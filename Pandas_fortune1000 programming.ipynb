# %%
import pandas as pd

# %%
df=pd.read_csv("fortune1000.csv")

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
cities=['pune','mumbai','nashik','satara']

# %%
df=pd.DataFrame(cities)
df
# Out:
#         0
# 0    pune
# 1  mumbai
# 2  nashik
# 3  satara

# %%
coties_info=[
    ['pune',9400000,330,18.52,73.85,False],
    ['mumbai',19400000,530,28.52,63.85,True],
    ['nagpur',4000000,230,34.52,43.85,True],
    ['aurangabad',28000,170,32.52,66.85,False]
]

# %%
df=pd.DataFrame(cities_info,
               columns=['city_name','population','area','lat','long','metro'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-df9008ca273d> in <module>
# ----> 1 df=pd.DataFrame(cities_info,
#       2                columns=['city_name','population','area','lat','long','metro'])
#       3 df
#
# NameError: name 'cities_info' is not defined

# %%
city_dict={
    'city':['mumbai','pune','nagpur','aurangabad'],
    'population':[63000,56000,12000,78000],
    'area':[555,333,222,180]
}

# %%
df=pd.DataFrame(city_dict)
df
# Out:
#          city  population  area
# 0      mumbai       63000   555
# 1        pune       56000   333
# 2      nagpur       12000   222
# 3  aurangabad       78000   180

# %%
df=pd.read_csv('fortune1000.csv')
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
#summary function
df.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.head().T
# Out:
#                                0                   1  \
# Rank                           1                   2
# Company                  Walmart         Exxon Mobil
# Sector                 Retailing              Energy
# Industry   General Merchandisers  Petroleum Refining
# Location         Bentonville, AR          Irving, TX
# Revenue                   482130              246204
# Profits                    14694               16150
# Employees                2300000               75600
#
#                                      2  \
# Rank                                 3
# Company                          Apple
# Sector                      Technology
# Industry   Computers, Office Equipment
# Location                 Cupertino, CA
# Revenue                         233715
# Profits                          53394
# Employees                       110000
#
#                                                   3                         4
# ...

# %%
df.head(15)
# Out:
#     Rank             Company                  Sector  \
# 0      1             Walmart               Retailing
# 1      2         Exxon Mobil                  Energy
# 2      3               Apple              Technology
# 3      4  Berkshire Hathaway              Financials
# 4      5            McKesson             Health Care
# 5      6  UnitedHealth Group             Health Care
# 6      7          CVS Health    Food and Drug Stores
# 7      8      General Motors  Motor Vehicles & Parts
# 8      9          Ford Motor  Motor Vehicles & Parts
# 9     10                AT&T      Telecommunications
# 10    11    General Electric             Industrials
# 11    12   AmerisourceBergen             Health Care
# 12    13             Verizon      Telecommunications
# 13    14             Chevron                  Energy
# 14    15              Costco               Retailing
#
#                                     Industry           Location  Revenue  \
# ...

# %%
df.tail()
# Out:
#      Rank                     Company                        Sector  \
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                         Industry       Location  Revenue  Profits  Employees
# 995             Commercial Banks   Westbury, NY     1902      -47       3448
# 996  Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 997  Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 998                Food Services     Dublin, OH     1896      161      21200
# 999         Industrial Machinery  Wauwatosa, WI     1895       46       5480

# %%
df.tail(11)
# Out:
#      Rank                     Company                        Sector  \
# 989   990                 F5 Networks                    Technology
# 990   991           BlueLinx Holdings                   Wholesalers
# 991   992                      Revlon            Household Products
# 992   993       DeVry Education Group             Business Services
# 993   994                MDC Holdings    Engineering & Construction
# 994   995                   EP Energy                        Energy
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                        Industry           Location  Revenue  \
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# ...

# %%
df.describe(include=['object'])
# Out:
#                       Company      Sector                    Industry  \
# count                    1000        1000                        1000
# unique                    996          21                          73
# top     Host Hotels & Resorts  Financials  Specialty Retailers: Other
# freq                        2         139                          42
#
#             Location
# count           1000
# unique           416
# top     New York, NY
# freq              72

# %%
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Company'])
# Out:
# pandas.core.series.Series

# %%
df['Company']
# Out:
# 0                         Walmart
# 1                     Exxon Mobil
# 2                           Apple
# 3              Berkshire Hathaway
# 4                        McKesson
#                   ...
# 995    New York Community Bancorp
# 996     Portland General Electric
# 997     Portland General Electric
# 998                       Wendy’s
# 999             Briggs & Stratton
# Name: Company, Length: 1000, dtype: object

# %%
df['Employees']
# Out:
# 0      2300000
# 1        75600
# 2       110000
# 3       331000
# 4        70400
#         ...
# 995       3448
# 996       2646
# 997       2646
# 998      21200
# 999       5480
# Name: Employees, Length: 1000, dtype: int64

# %%
df[['Company','Employees']]
# Out:
#                         Company  Employees
# 0                       Walmart    2300000
# 1                   Exxon Mobil      75600
# 2                         Apple     110000
# 3            Berkshire Hathaway     331000
# 4                      McKesson      70400
# ..                          ...        ...
# 995  New York Community Bancorp       3448
# 996   Portland General Electric       2646
# 997   Portland General Electric       2646
# 998                     Wendy’s      21200
# 999           Briggs & Stratton       5480
#
# [1000 rows x 2 columns]

# %%
df[['Company','Employees','Sector']]
# Out:
#                         Company  Employees                        Sector
# 0                       Walmart    2300000                     Retailing
# 1                   Exxon Mobil      75600                        Energy
# 2                         Apple     110000                    Technology
# 3            Berkshire Hathaway     331000                    Financials
# 4                      McKesson      70400                   Health Care
# ..                          ...        ...                           ...
# 995  New York Community Bancorp       3448                    Financials
# 996   Portland General Electric       2646                        Energy
# 997   Portland General Electric       2646                        Energy
# 998                     Wendy’s      21200  Hotels, Resturants & Leisure
# 999           Briggs & Stratton       5480                   Industrials
#
# [1000 rows x 3 columns]

# %%
#adding a new column into df
df['Game']="basketball"
df.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees        Game
# 0    14694    2300000  basketball
# 1    16150      75600  basketball
# 2    53394     110000  basketball
# 3    24083     331000  basketball
# 4     1476      70400  basketball

# %%
df['Tax']=df['Employees']*0.1
df.head
# Out:
# <bound method NDFrame.head of      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# ...

# %%
#indexing loc,iloc
df.iloc[0]
# Out:
# Rank                             1
# Company                    Walmart
# Sector                   Retailing
# Industry     General Merchandisers
# Location           Bentonville, AR
# Revenue                     482130
# Profits                      14694
# Employees                  2300000
# Game                    basketball
# Tax                         230000
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#    Rank             Company      Sector  \
# 0     1             Walmart   Retailing
# 1     2         Exxon Mobil      Energy
# 2     3               Apple  Technology
# 3     4  Berkshire Hathaway  Financials
#
#                                    Industry         Location  Revenue  \
# 0                     General Merchandisers  Bentonville, AR   482130
# 1                        Petroleum Refining       Irving, TX   246204
# 2               Computers, Office Equipment    Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)        Omaha, NE   210821
#
#    Profits  Employees        Game       Tax
# 0    14694    2300000  basketball  230000.0
# 1    16150      75600  basketball    7560.0
# 2    53394     110000  basketball   11000.0
# 3    24083     331000  basketball   33100.0

# %%
df.iloc[0:4,0:4]
# Out:
#    Rank             Company      Sector  \
# 0     1             Walmart   Retailing
# 1     2         Exxon Mobil      Energy
# 2     3               Apple  Technology
# 3     4  Berkshire Hathaway  Financials
#
#                                    Industry
# 0                     General Merchandisers
# 1                        Petroleum Refining
# 2               Computers, Office Equipment
# 3  Insurance: Property and Casualty (Stock)

# %%
df.iloc[0:4,0:6:2]
# Out:
#    Rank      Sector         Location
# 0     1   Retailing  Bentonville, AR
# 1     2      Energy       Irving, TX
# 2     3  Technology    Cupertino, CA
# 3     4  Financials        Omaha, NE

# %%
df.iloc[0:10:2,0:8:2]
# Out:
#    Rank                  Sector           Location  Profits
# 0     1               Retailing    Bentonville, AR    14694
# 2     3              Technology      Cupertino, CA    53394
# 4     5             Health Care  San Francisco, CA     1476
# 6     7    Food and Drug Stores     Woonsocket, RI     5237
# 8     9  Motor Vehicles & Parts       Dearborn, MI     7373

# %%
df.iloc[0:100]['Company']
# Out:
# 0                      Walmart
# 1                  Exxon Mobil
# 2                        Apple
# 3           Berkshire Hathaway
# 4                     McKesson
#                 ...
# 95    Twenty-First Century Fox
# 96                       Deere
# 97                      Tesoro
# 98                 Time Warner
# 99         Northwestern Mutual
# Name: Company, Length: 100, dtype: object

# %%
df.iloc[0:100]['Company']
# Out:
# 0                      Walmart
# 1                  Exxon Mobil
# 2                        Apple
# 3           Berkshire Hathaway
# 4                     McKesson
#                 ...
# 95    Twenty-First Century Fox
# 96                       Deere
# 97                      Tesoro
# 98                 Time Warner
# 99         Northwestern Mutual
# Name: Company, Length: 100, dtype: object

# %%
#first 10 row and first 10 columns
df.iloc[:10,:10]
# Out:
#    Rank             Company                  Sector  \
# 0     1             Walmart               Retailing
# 1     2         Exxon Mobil                  Energy
# 2     3               Apple              Technology
# 3     4  Berkshire Hathaway              Financials
# 4     5            McKesson             Health Care
# 5     6  UnitedHealth Group             Health Care
# 6     7          CVS Health    Food and Drug Stores
# 7     8      General Motors  Motor Vehicles & Parts
# 8     9          Ford Motor  Motor Vehicles & Parts
# 9    10                AT&T      Telecommunications
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
df.iloc[300:,4:]
# Out:
#             Location  Revenue  Profits  Employees        Game     Tax
# 300        Miami, FL     9474      803       7749  basketball   774.9
# 301    Grapevine, TX     9364      403      40600  basketball  4060.0
# 302  Los Angeles, CA     9351      312      13400  basketball  1340.0
# 303       Austin, MN     9264      686      20700  basketball  2070.0
# 304       Summit, NJ     9256     1602       6971  basketball   697.1
# ..               ...      ...      ...        ...         ...     ...
# 995     Westbury, NY     1902      -47       3448  basketball   344.8
# 996     Portland, OR     1898      172       2646  basketball   264.6
# 997     Portland, OR     1898      172       2646  basketball   264.6
# 998       Dublin, OH     1896      161      21200  basketball  2120.0
# 999    Wauwatosa, WI     1895       46       5480  basketball   548.0
#
# [700 rows x 6 columns]

# %%
df.iloc[0][4]
# Out:
# 'Bentonville, AR'

# %%
df.iloc[0][4:8]
# Out:
# Location     Bentonville, AR
# Revenue               482130
# Profits                14694
# Employees            2300000
# Name: 0, dtype: object

# %%
df.iloc[0]['Revenue']
# Out:
# 482130

# %%
df.iloc[0]['Sector']
# Out:
# 'Retailing'

# %%
#Cheacking null value
df.isnull
# Out:
# <bound method DataFrame.isnull of      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# ...

# %%
df.isnull().sum()
# Out:
# Rank         0
# Company      0
# Sector       0
# Industry     0
# Location     0
# Revenue      0
# Profits      0
# Employees    0
# Game         0
# Tax          0
# dtype: int64

# %%
df.isnull().mean()*10
# Out:
# Rank         0.0
# Company      0.0
# Sector       0.0
# Industry     0.0
# Location     0.0
# Revenue      0.0
# Profits      0.0
# Employees    0.0
# Game         0.0
# Tax          0.0
# dtype: float64

# %%
df.isnull().mean()*100
# Out:
# Rank         0.0
# Company      0.0
# Sector       0.0
# Industry     0.0
# Location     0.0
# Revenue      0.0
# Profits      0.0
# Employees    0.0
# Game         0.0
# Tax          0.0
# dtype: float64

# %%
#Series related function
df['Revenue'].sum()
# Out:
# 13535525

# %%
df['Revenue'].max()
# Out:
# 482130

# %%
df['Revenue'].min()
# Out:
# 1895

# %%
df['Revenue'].mean()
# Out:
# 13535.525

# %%
df['Revenue'].var()
# Out:
# 830622323.2045898

# %%
df['Revenue'].median()
# Out:
# 5113.0

# %%
df['Revenue'].mode()
# Out:
# 0    2084
# 1    2197
# 2    2986
# dtype: int64

# %%
df['Revenue'].max()
# Out:
# 482130

# %%
df['Revenue'].unique()
# Out:
# array([482130, 246204, 233715, 210821, 181241, 157107, 153290, 152356,
#        149558, 146801, 140389, 135962, 131620, 131118, 116199, 110359,
#        109830, 107006, 103444, 103355, 102531, 101752, 101006,  96114,
#         93580,  93056,  90033,  88519,  88275,  87169,  82461,  81824,
#         79157,  78756,  75697,  74989,  74510,  73785,  70074,  69951,
#         67702,  64566,  63491,  63056,  61047,  60337,  59074,  58363,
#         58327,  57119,  55355,  54289,  52465,  49161,  48851,  48778,
#         48681,  47453,  47011,  46132,  45891,  44294,  43591,  43026,
#         42126,  41373,  40990,  40704,  40222,  40204,  39745,  39498,
#         39450,  39208,  38581,  38243,  38226,  37897,  37876,  37864,
#         35653,  35181,  34693,  34582,  34441,  32639,  32619,  31469,
#         30945,  30935,  30601,  30380,  30274,  29636,  29447,  28987,
#         28863,  28150,  28118,  28111,  27940,  27925,  27079,  27028,
# ...

# %%
#deletion operation

# %%
df.drop(['Game']),axis=1 ,inplace=True
df
# Out:
#   File "<ipython-input-78-d2ae47b0cc4a>", line 1
#     df.drop(['Game']),axis=1 ,inplace=True
#     ^
# SyntaxError: cannot assign to function call

# %%
#iterrating over data in dff

# %%
for i in df:
    print(i)
# Out:
# Rank
# Company
# Sector
# Industry
# Location
# Revenue
# Profits
# Employees
# Game
# Tax

# %%
for i in df,itrrows():
    print(i)
    print(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-1673d75c3d5b> in <module>
# ----> 1 for i in df,itrrows():
#       2     print(i)
#       3     print(j)
#
# NameError: name 'itrrows' is not defined
